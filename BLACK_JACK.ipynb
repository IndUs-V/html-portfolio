# %%
# def name(first_name,last_name ):
#     new_first_word = ""
#     for i in range(0, len(first_name)):
#         n=first_name[i]
#         if i == 0:
#             new_first_word += n.upper()
#         else:
#             new_first_word += n.lower()
#     new_first_word+=" "
#     new_last_word = ""
#     for i in range(0, len(last_name)):
#         n = last_name[i]
#         if i == 0:
#             new_last_word += n.upper()
#         else:
#             new_last_word += n.lower()
#     final_name = new_first_word+new_last_word
#     return final_name


# a = input("Enter the first name")
# b = input("Enter the last name")
# print("Your grammatically correct name is:",end="\n")
# name(first_name=a , last_name=b)

# def name(first_name,last_name ):

#     new_first_word =first_name.title()
#     new_last_word =last_name.title()
#     final_name = new_first_word+" "+new_last_word
#     return final_name
# a = input("Enter the first name")
# b = input("Enter the last name")
# print("Your grammatically correct name is:",end="\n")
# name(first_name=a , last_name=b)

#DAY 10-CHALLENGE-CALCULATOR




#Day 11-VLACK JACK-Challenge

print("""
            _____                    _____      _____                    _____                    _____                                                    _____                    _____                    _____                    _____
           /\    \                  /\    \    /\    \                  /\    \                  /\    \                                                  /\    \                  /\    \                  /\    \                  /\    \*
          /::\    \                /::\____\  /::\    \                /::\    \                /::\____\                                                /::\    \                /::\    \                /::\    \                /::\____\*
         /::::\    \              /:::/    / /::::\    \              /::::\    \              /:::/    /                                                \:::\    \              /::::\    \              /::::\    \              /:::/    /
        /::::::\    \            /:::/    / /::::::\    \            /::::::\    \            /:::/    /                                                  \:::\    \            /::::::\    \            /::::::\    \            /:::/    /
       /:::/\:::\    \          /:::/    / /:::/\:::\    \          /:::/\:::\    \          /:::/    /                                                    \:::\    \          /:::/\:::\    \          /:::/\:::\    \          /:::/    /
      /:::/__\:::\    \        /:::/    / /:::/__\:::\    \        /:::/  \:::\    \        /:::/____/                                                      \:::\    \        /:::/__\:::\    \        /:::/  \:::\    \        /:::/____/
     /::::\   \:::\    \      /:::/    / /::::\   \:::\    \      /:::/    \:::\    \      /::::\    \                                                      /::::\    \      /::::\   \:::\    \      /:::/    \:::\    \      /::::\    \*
    /::::::\   \:::\    \    /:::/    / /::::::\   \:::\    \    /:::/    / \:::\    \    /::::::\____\________                                    _____   /::::::\    \    /::::::\   \:::\    \    /:::/    / \:::\    \    /::::::\____\________
   /:::/\:::\   \:::\ ___\  /:::/    / /:::/\:::\   \:::\    \  /:::/    /   \:::\    \  /:::/\:::::::::::\    \                                  /\    \ /:::/\:::\    \  /:::/\:::\   \:::\    \  /:::/    /   \:::\    \  /:::/\:::::::::::\    \*
  /:::/__\:::\   \:::|    |/:::/____/ /:::/  \:::\   \:::\____\/:::/____/     \:::\____\/:::/  |:::::::::::\____\                                /::\    /:::/  \:::\____\/:::/  \:::\   \:::\____\/:::/____/     \:::\____\/:::/  |:::::::::::\____\*
  \:::\   \:::\  /:::|____|\:::\    \ \::/    \:::\  /:::/    /\:::\    \      \::/    /\::/   |::|~~~|~~~~~                                     \:::\  /:::/    \::/    /\::/    \:::\  /:::/    /\:::\    \      \::/    /\::/   |::|~~~|~~~~~
   \:::\   \:::\/:::/    /  \:::\    \ \/____/ \:::\/:::/    /  \:::\    \      \/____/  \/____|::|   |                                           \:::\/:::/    / \/____/  \/____/ \:::\/:::/    /  \:::\    \      \/____/  \/____|::|   |
    \:::\   \::::::/    /    \:::\    \         \::::::/    /    \:::\    \                    |::|   |                                            \::::::/    /                    \::::::/    /    \:::\    \                    |::|   |
     \:::\   \::::/    /      \:::\    \         \::::/    /      \:::\    \                   |::|   |                                             \::::/    /                      \::::/    /      \:::\    \                   |::|   |
      \:::\  /:::/    /        \:::\    \        /:::/    /        \:::\    \                  |::|   |                                              \::/    /                       /:::/    /        \:::\    \                  |::|   |
       \:::\/:::/    /          \:::\    \      /:::/    /          \:::\    \                 |::|   |                                               \/____/                       /:::/    /          \:::\    \                 |::|   |
        \::::::/    /            \:::\    \    /:::/    /            \:::\    \                |::|   |                                                                            /:::/    /            \:::\    \                |::|   |
         \::::/    /              \:::\____\  /:::/    /              \:::\____\               \::|   |                                                                           /:::/    /              \:::\____\               \::|   |
          \::/____/                \::/    /  \::/    /                \::/    /                \:|   |                                                                           \::/    /                \::/    /                \:|   |
           ~~                       \/____/    \/____/                  \/____/                  \|___|                                                                            \/____/                  \/____/                  \|___|






                                                                                                                  ,------.
    ,---.  ,------. ,------.    ,--.   ,--.,-----. ,--. ,--.    ,------. ,------.  ,---.  ,------.,--.   ,--.    '  .--.  '
   /  O  \ |  .--. '|  .---'     \  `.'  /'  .-.  '|  | |  |    |  .--. '|  .---' /  O  \ |  .-.  \\  `.'  /     '--' _|  |
  |  .-.  ||  '--'.'|  `--,       '.    / |  | |  ||  | |  |    |  '--'.'|  `--, |  .-.  ||  |  \  :'.    /       .--' __'
  |  | |  ||  |\  \ |  `---.        |  |  '  '-'  ''  '-'  '    |  |\  \ |  `---.|  | |  ||  '--'  /  |  |        `---'
  `--' `--'`--' '--'`------'        `--'   `-----'  `-----'     `--' '--'`------'`--' `--'`-------'   `--'        .---.
                                                                                                                  '---'
""")


# First decide the bet amount
# During the game, you get to see two of your own cards. The computer has two cards, but only one is revealed
# Neither should cross 21
# You can either hit or stand
# After that, computer reveals its other card. If sum<16, it keeps drawing more cards.
# Whoever is less than or equal to 21 and also has higher sum wins
#Ace always gives favourable outcome
#Natural balck-jack is always the winner

#Actual Code:

import random
bank_money=random.randint(300,1000)
bet=float(input("Enter the amount that you want to bet for the upcoming match"))
Begin=input("Enter 'Start' To Begin The Match")
List_of_cards=["A",2,3,4,5,6,7,8,9,"J","Q","K"]
if(Begin=='Start'):
    PC_card_1=List_of_cards[random.randint(0,11)]
    PC_card_2=List_of_cards[random.randint(0,11)]
    Player_card_1=List_of_cards[random.randint(0,11)]
    Player_card_2=List_of_cards[random.randint(0,11)]
    print(f"""You cards:
            Card 1:{Player_card_1}
            Card 2: {Player_card_2}
        """)
    print(f"""Computer's cards:
            Card 1: {PC_card_1}
            Card 2:  ?
        """)
    #PLAYER SCORE
    #First Block
    if(Player_card_1=="J" or Player_card_1=="Q" or Player_card_1=="K" or Player_card_1=="A"):
        Player_score_1=10
    elif(1<Player_card_1<10):
        Player_score_1=Player_card_1
    #Second Block
    if(Player_card_2=="J" or Player_card_2=="Q" or Player_card_2=="K" or Player_card_2=="A"):
        Player_score_2=10
    elif(1<Player_card_2<10):
        Player_score_2=Player_card_2
    #Final score
    if(Player_score_1+Player_score_2>21 and Player_card_1=="A"):
        Player_final_score=1+Player_score_2
    elif(Player_score_1+Player_score_2>21 and Player_card_2=="A"):
        Player_final_score=1+Player_score_1
    else:
        Player_final_score=Player_score_1+Player_score_2
    if(Player_final_score==21):
        print("Player Wins")
    #PC SCORE
    #First Block
    if(PC_card_1=="J" or PC_card_1=="Q" or PC_card_1=="K" or PC_card_1=="A"):
        PC_score_1=10
    elif(1<PC_card_1<10):
        PC_score_1=PC_card_1
    #Second Block
    if(PC_card_2=="J" or PC_card_2=="Q" or PC_card_2=="K" or PC_card_2=="A"):
        PC_score_2=10
    elif(1<PC_card_2<10):
        PC_score_2=PC_card_2
    #Third Block
    if(PC_score_1+PC_score_2>21 and PC_card_1=="A"):
        PC_final_score=1+PC_score_2
    elif(PC_score_1+PC_score_2>21 and PC_card_2=="A"):
        PC_final_score=1+PC_score_1
    else:
        PC_final_score=PC_score_1+PC_score_2
    print(f"Computer's 2nd card:{PC_card_2}")
    #Getting new cards till sum is greater than 16
    i=3
    while(PC_final_score<=16):
        new_card=List_of_cards[random.randint(0,11)]
        if(new_card=="J" or new_card=="Q" or new_card=="K" or new_card=="A"):
            PC_new_card_score=10
        elif(1<new_card<10):
            PC_new_card_score=new_card
        if(PC_final_score+PC_new_card_score>21 and new_card=="A"):
            PC_final_score+=1
        else:
            PC_final_score+=PC_new_card_score
        print(f"Computer's {i}th card: {new_card}")
        i+=1
    #Decide the winner
        
    if(Player_final_score==PC_final_score):
        print("Tie")
    elif(PC_final_score<Player_final_score<=21):
        print("Player Wins")
    elif(Player_final_score<=21 and PC_final_score>21):
        print("Player Wins")
    elif(PC_final_score<=21 and Player_final_score>21):
        print("PC Wins")
    elif(Player_final_score<PC_final_score<=21):
        print("PC wins")
        
#Features to be added: Player should be able to select third card and also split cards. See if list method could be used to reduce code size
# Out:
# <>:44: SyntaxWarning: invalid escape sequence '\ '
# <>:44: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/3v/2g2nlfy96xj1n2q9lpt4ytqm0000gn/T/ipykernel_735/4236244307.py:44: SyntaxWarning: invalid escape sequence '\ '
#   print("""
#             _____                    _____      _____                    _____                    _____                                                    _____                    _____                    _____                    _____
#            /\    \                  /\    \    /\    \                  /\    \                  /\    \                                                  /\    \                  /\    \                  /\    \                  /\    \*
#           /::\    \                /::\____\  /::\    \                /::\    \                /::\____\                                                /::\    \                /::\    \                /::\    \                /::\____\*
# ...
